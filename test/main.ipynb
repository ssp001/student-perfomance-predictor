# %%
import pandas as pd

# %%
data_set=pd.read_csv(r"C:\Users\shova\Desktop\project\student performance detector\data\StudentPerformanceFactors.csv")

# %%
data_set.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
data_set.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(data_set.isnull())
plt.show()

# %%
data_set.shape
# Out:
# (6607, 20)

# %%
data_set.dropna(inplace=True)

# %%
data_set
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
data_set.isnull().sum()
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Peer_Influence                0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %%
data_set.shape
# Out:
# (6378, 20)

# %%
data_set.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
data_set['Parental_Involvement'].unique()
# Out:
# <StringArray>
# ['Low', 'Medium', 'High']
# Length: 3, dtype: str

# %%
ord_data=[['Low', 'Medium', 'High']]

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe=OrdinalEncoder(categories=ord_data)

# %%
oe.fit(data_set[['Parental_Involvement']])
# Out:
# OrdinalEncoder(categories=[['Low', 'Medium', 'High']])

# %%
data_set[['Parental_Involvement']]=oe.fit_transform(data_set[['Parental_Involvement']])

# %%
data_set
# Out:
#       Hours_Studied  Attendance  Parental_Involvement Access_to_Resources  \
# 0                23          84                   0.0                High
# 1                19          64                   0.0              Medium
# 2                24          98                   1.0              Medium
# 3                29          89                   0.0              Medium
# 4                19          92                   1.0              Medium
# ...             ...         ...                   ...                 ...
# 6602             25          69                   2.0              Medium
# 6603             23          76                   2.0              Medium
# 6604             20          90                   1.0                 Low
# 6605             10          86                   2.0                High
# 6606             15          67                   1.0                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
data_set["Access_to_Resources"].unique()
ord_data=[['Low', 'Medium', 'High']]
oe=OrdinalEncoder(categories=ord_data)
data_set[["Access_to_Resources"]]=oe.fit_transform(data_set[["Access_to_Resources"]])

# %%
data_set
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                   0.0                  2.0
# 1                19          64                   0.0                  1.0
# 2                24          98                   1.0                  1.0
# 3                29          89                   0.0                  1.0
# 4                19          92                   1.0                  1.0
# ...             ...         ...                   ...                  ...
# 6602             25          69                   2.0                  1.0
# 6603             23          76                   2.0                  1.0
# 6604             20          90                   1.0                  0.0
# 6605             10          86                   2.0                  2.0
# 6606             15          67                   1.0                  0.0
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
data_set["Motivation_Level"].unique()
ord_data=[['Low', 'Medium', 'High']]
oe=OrdinalEncoder(categories=ord_data)
data_set[["Motivation_Level"]]=oe.fit_transform(data_set[["Motivation_Level"]])

# %%
data_set
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                   0.0                  2.0
# 1                19          64                   0.0                  1.0
# 2                24          98                   1.0                  1.0
# 3                29          89                   0.0                  1.0
# 4                19          92                   1.0                  1.0
# ...             ...         ...                   ...                  ...
# 6602             25          69                   2.0                  1.0
# 6603             23          76                   2.0                  1.0
# 6604             20          90                   1.0                  0.0
# 6605             10          86                   2.0                  2.0
# 6606             15          67                   1.0                  0.0
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
data_set['Extracurricular_Activities'].unique()
# Out:
# <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str

# %%
data_set['Family_Income'].unique()
ord_data=[['Low', 'Medium', 'High']]
oe=OrdinalEncoder(categories=ord_data)
data_set[["Family_Income"]]=oe.fit_transform(data_set[["Family_Income"]])

# %%
data_set
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                   0.0                  2.0
# 1                19          64                   0.0                  1.0
# 2                24          98                   1.0                  1.0
# 3                29          89                   0.0                  1.0
# 4                19          92                   1.0                  1.0
# ...             ...         ...                   ...                  ...
# 6602             25          69                   2.0                  1.0
# 6603             23          76                   2.0                  1.0
# 6604             20          90                   1.0                  0.0
# 6605             10          86                   2.0                  2.0
# 6606             15          67                   1.0                  0.0
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
data_set['Teacher_Quality'].unique()
ord_data=[['Low', 'Medium', 'High']]
oe=OrdinalEncoder(categories=ord_data)
data_set[["Teacher_Quality"]]=oe.fit_transform(data_set[["Teacher_Quality"]])

# %%
data_set['Peer_Influence'].unique()
ord_data=[['Positive', 'Negative', 'Neutral']]
oe=OrdinalEncoder(categories=ord_data)
data_set[["Peer_Influence"]]=oe.fit_transform(data_set[["Peer_Influence"]])

# %%
data_set
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                   0.0                  2.0
# 1                19          64                   0.0                  1.0
# 2                24          98                   1.0                  1.0
# 3                29          89                   0.0                  1.0
# 4                19          92                   1.0                  1.0
# ...             ...         ...                   ...                  ...
# 6602             25          69                   2.0                  1.0
# 6603             23          76                   2.0                  1.0
# 6604             20          90                   1.0                  0.0
# 6605             10          86                   2.0                  2.0
# 6606             15          67                   1.0                  0.0
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder(drop="first")

# %%
en_data=data_set[['Extracurricular_Activities','Internet_Access','School_Type','Learning_Disabilities','Gender']]

# %%
array=ohe.fit_transform(en_data).toarray()

# %%
data_set[['Extracurricular_Activities','Internet_Access','School_Type','Learning_Disabilities','Gender']]=pd.DataFrame(array,columns=['Extracurricular_Activities','Internet_Access','School_Type','Learning_Disabilities','Gender'])

# %%
data_set
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                   0.0                  2.0
# 1                19          64                   0.0                  1.0
# 2                24          98                   1.0                  1.0
# 3                29          89                   0.0                  1.0
# 4                19          92                   1.0                  1.0
# ...             ...         ...                   ...                  ...
# 6602             25          69                   2.0                  1.0
# 6603             23          76                   2.0                  1.0
# 6604             20          90                   1.0                  0.0
# 6605             10          86                   2.0                  2.0
# 6606             15          67                   1.0                  0.0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
ordinal_cols = [
                'Parental_Involvement',
                'Access_to_Resources',
                'Motivation_Level',
                'Family_Income',
                'Teacher_Quality',
                'Peer_Influence',
                'Parental_Education_Level',
                'Distance_from_Home'
            ]
oe =OrdinalEncoder(categories=ordinal_cols)

# %%
# performing ordinal encoding in some colums.
data_set[ordinal_cols] = oe.fit_transform(data_set[ordinal_cols])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 2
#       1             # performing ordinal encoding in some colums.
# ----> 2 data_set[ordinal_cols] = oe.fit_transform(data_set[ordinal_cols])
#
# File c:\Users\shova\Desktop\project\student performance detector\.venv\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# ...

# %%
data_set.dropna(inplace=True)

# %%
data_set.isnull().sum()
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Peer_Influence                0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %%
data_set.shape
# Out:
# (6162, 20)

# %%
data_set['Parental_Education_Level'].unique()
ord_data=[['High School', 'College', 'Postgraduate']]
oe=OrdinalEncoder(categories=ord_data)
data_set[["Parental_Education_Level"]]=oe.fit_transform(data_set[["Parental_Education_Level"]])

# %%
data_set.head()
# Out:
#    Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0             23          84                   0.0                  2.0
# 1             19          64                   0.0                  1.0
# 2             24          98                   1.0                  1.0
# 3             29          89                   0.0                  1.0
# 4             19          92                   1.0                  1.0
#
#    Extracurricular_Activities  Sleep_Hours  Previous_Scores  Motivation_Level  \
# 0                         0.0            7               73               0.0
# 1                         0.0            8               59               0.0
# 2                         1.0            7               91               1.0
# 3                         1.0            8               98               1.0
# 4                         1.0            6               65               1.0
#
# ...

# %%
data_set['Distance_from_Home'].unique()
ord_data=[['Near', 'Moderate', 'Far']]
oe=OrdinalEncoder(categories=ord_data)
data_set[["Distance_from_Home"]]=oe.fit_transform(data_set[["Distance_from_Home"]])

# %%
data_set.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 6162 entries, 0 to 6377
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6162 non-null   int64
#  1   Attendance                  6162 non-null   int64
#  2   Parental_Involvement        6162 non-null   float64
#  3   Access_to_Resources         6162 non-null   float64
#  4   Extracurricular_Activities  6162 non-null   float64
#  5   Sleep_Hours                 6162 non-null   int64
#  6   Previous_Scores             6162 non-null   int64
#  7   Motivation_Level            6162 non-null   float64
#  8   Internet_Access             6162 non-null   float64
#  9   Tutoring_Sessions           6162 non-null   int64
#  10  Family_Income               6162 non-null   float64
#  11  Teacher_Quality             6162 non-null   float64
#  12  School_Type                 6162 non-null   float64
# ...

# %%
sns.scatterplot(data_set)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=data_set.iloc[:,:-1]
y=data_set.iloc[::,-1]

# %%
y
# Out:
# 0       67
# 1       61
# 2       74
# 3       71
# 4       70
#         ..
# 6373    66
# 6374    71
# 6375    68
# 6376    68
# 6377    71
# Name: Exam_Score, Length: 6162, dtype: int64

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr=RandomForestRegressor(   n_estimators=500,
    max_depth=15,
    min_samples_split=5,
    random_state=42)

# %%
rfr.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=15, min_samples_split=5, n_estimators=500,
#                       random_state=42)

# %%
y_pred = rfr.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("MAE:", mae)
print("RMSE:", rmse)
print("R2 Score:", r2)
# Out:
# MAE: 1.1279512713806195
# RMSE: 2.1993372153492885
# R2 Score: 0.6738013957123993
